# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import os 
import pily as pl

# %%
#con el archivo pily.py
df = pl.cargar_dataset ('Francia.csv')
df
# Out:
#       Unnamed: 0                                             name    host_id  \
# 0              0                    Duplex avec vue, centre ville     269557
# 1              1                  Nice Flat in the center of Lyon     411285
# 2              2               Centre of old town,home sweet home     660135
# 3              3              Bel apartment, 2 rooms, Lyon center     670404
# 4              4  Quartier Terreaux 4/6 pers. Hyper centre / Clim     832917
# ...          ...                                              ...        ...
# 9886        9886                                      Suite Rumba  651608878
# 9887        9887                                      Suite Zelie  651608878
# 9888        9888                    Havre de Paix au Cœur du 7ème  666633599
# 9889        9889                           Le Duplex avec Rooftop   12466813
# 9890        9890                                          L’opéra  417340177
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9891 entries, 0 to 9890
# Data columns (total 51 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Unnamed: 0                                     9891 non-null   int64
#  1   name                                           9891 non-null   object
#  2   host_id                                        9891 non-null   int64
#  3   host_name                                      9889 non-null   object
#  4   host_since                                     9889 non-null   object
#  5   host_location                                  8367 non-null   object
#  6   host_about                                     3825 non-null   object
#  7   host_response_time                             5235 non-null   object
#  8   host_response_rate                             5235 non-null   float64
# ...

# %%
#Valores nulos
nulos = pl.valores_nulos(df)
nulos
# Out:
# ('Valores nulos por columna',
#  Unnamed: 0                                          0
#  name                                                0
#  host_id                                             0
#  host_name                                           2
#  host_since                                          2
#  host_location                                    1524
#  host_about                                       6066
#  host_response_time                               4656
#  host_response_rate                               4656
#  host_is_superhost                                 211
#  host_neighbourhood                               5544
#  host_listings_count                                 2
#  host_total_listings_count                           2
#  host_identity_verified                              2
#  neighbourhood_cleansed                              0
#  latitude                                            0
# ...

# %%
df1 = df.copy()

# %%
df2 = df.copy()

# %%
df3 = df.copy()

# %%
df4 = df.copy()

# %%
df5 = df.copy()

# %%
df6 = df.copy()

# %% [markdown]
# **FORWARD FILL - FFILL**

# %%
ffill = pl.sustitucion_ffill(df1,'bathrooms')
ffill
# Out:
# /Users/pilymendez/Desktop/Profe Alfredo /5_Funciones/pily.py:41: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[col] = df[col].fillna(method='ffill')
#       Unnamed: 0                                             name    host_id  \
# 0              0                    Duplex avec vue, centre ville     269557
# 1              1                  Nice Flat in the center of Lyon     411285
# 2              2               Centre of old town,home sweet home     660135
# 3              3              Bel apartment, 2 rooms, Lyon center     670404
# 4              4  Quartier Terreaux 4/6 pers. Hyper centre / Clim     832917
# ...          ...                                              ...        ...
# 9886        9886                                      Suite Rumba  651608878
# 9887        9887                                      Suite Zelie  651608878
# ...

# %%
pl.valores_nulos(ffill)
# Out:
# ('Valores nulos por columna',
#  Unnamed: 0                                          0
#  name                                                0
#  host_id                                             0
#  host_name                                           2
#  host_since                                          2
#  host_location                                    1524
#  host_about                                       6066
#  host_response_time                               4656
#  host_response_rate                               4656
#  host_is_superhost                                 211
#  host_neighbourhood                               5544
#  host_listings_count                                 2
#  host_total_listings_count                           2
#  host_identity_verified                              2
#  neighbourhood_cleansed                              0
#  latitude                                            0
# ...

# %%
csv1 = pl.convertir_a_csv (ffill,'01_Ffill.csv')

# %% [markdown]
# **BACKWARD FILL - BFILL**

# %%
bfill = pl.sustitución_bfill(df2)
bfill
# Out:
# /Users/pilymendez/Desktop/Profe Alfredo /5_Funciones/pily.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   cualitativas = cualitativas.fillna(method="bfill")
#       Unnamed: 0                                             name    host_id  \
# 0              0                    Duplex avec vue, centre ville     269557
# 1              1                  Nice Flat in the center of Lyon     411285
# 2              2               Centre of old town,home sweet home     660135
# 3              3              Bel apartment, 2 rooms, Lyon center     670404
# 4              4  Quartier Terreaux 4/6 pers. Hyper centre / Clim     832917
# ...          ...                                              ...        ...
# 9886        9886                                      Suite Rumba  651608878
# 9887        9887                                      Suite Zelie  651608878
# ...

# %%
pl.valores_nulos(bfill)
# Out:
# ('Valores nulos por columna',
#  Unnamed: 0                                          0
#  name                                                0
#  host_id                                             0
#  host_name                                           0
#  host_since                                          0
#  host_location                                       0
#  host_about                                          6
#  host_response_time                                  0
#  host_response_rate                               4656
#  host_is_superhost                                   1
#  host_neighbourhood                                 11
#  host_listings_count                                 2
#  host_total_listings_count                           2
#  host_identity_verified                              0
#  neighbourhood_cleansed                              0
#  latitude                                            0
# ...

# %%
csv2 = pl.convertir_a_csv (bfill,'02_bfill.csv')

# %% [markdown]
# **STRING CONCRETO**

# %%
concreto = pl.sustitucion_string(df3,'host_about')
concreto
# Out:
#       Unnamed: 0                                             name    host_id  \
# 0              0                    Duplex avec vue, centre ville     269557
# 1              1                  Nice Flat in the center of Lyon     411285
# 2              2               Centre of old town,home sweet home     660135
# 3              3              Bel apartment, 2 rooms, Lyon center     670404
# 4              4  Quartier Terreaux 4/6 pers. Hyper centre / Clim     832917
# ...          ...                                              ...        ...
# 9886        9886                                      Suite Rumba  651608878
# 9887        9887                                      Suite Zelie  651608878
# 9888        9888                    Havre de Paix au Cœur du 7ème  666633599
# 9889        9889                           Le Duplex avec Rooftop   12466813
# 9890        9890                                          L’opéra  417340177
#
# ...

# %%
pl.valores_nulos(concreto)
# Out:
# ('Valores nulos por columna',
#  Unnamed: 0                                          0
#  name                                                0
#  host_id                                             0
#  host_name                                           2
#  host_since                                          2
#  host_location                                    1524
#  host_about                                          0
#  host_response_time                               4656
#  host_response_rate                               4656
#  host_is_superhost                                 211
#  host_neighbourhood                               5544
#  host_listings_count                                 2
#  host_total_listings_count                           2
#  host_identity_verified                              2
#  neighbourhood_cleansed                              0
#  latitude                                            0
# ...

# %%
csv3 = pl.convertir_a_csv (concreto,'03_string.csv')

# %% [markdown]
# **PROMEDIO**

# %%
promedio = pl.promedio(df4,'review_scores_rating')
promedio
# Out:
#       Unnamed: 0                                             name    host_id  \
# 0              0                    Duplex avec vue, centre ville     269557
# 1              1                  Nice Flat in the center of Lyon     411285
# 2              2               Centre of old town,home sweet home     660135
# 3              3              Bel apartment, 2 rooms, Lyon center     670404
# 4              4  Quartier Terreaux 4/6 pers. Hyper centre / Clim     832917
# ...          ...                                              ...        ...
# 9886        9886                                      Suite Rumba  651608878
# 9887        9887                                      Suite Zelie  651608878
# 9888        9888                    Havre de Paix au Cœur du 7ème  666633599
# 9889        9889                           Le Duplex avec Rooftop   12466813
# 9890        9890                                          L’opéra  417340177
#
# ...

# %%
pl.valores_nulos(promedio)
# Out:
# ('Valores nulos por columna',
#  Unnamed: 0                                          0
#  name                                                0
#  host_id                                             0
#  host_name                                           2
#  host_since                                          2
#  host_location                                    1524
#  host_about                                       6066
#  host_response_time                               4656
#  host_response_rate                               4656
#  host_is_superhost                                 211
#  host_neighbourhood                               5544
#  host_listings_count                                 2
#  host_total_listings_count                           2
#  host_identity_verified                              2
#  neighbourhood_cleansed                              0
#  latitude                                            0
# ...

# %%
csv4 = pl.convertir_a_csv (promedio,'04_promedio.csv')

# %% [markdown]
# **MEDIANA**

# %%
#Columnas numéricas donde hay valores extremos y el promedio podría estar distorsionado
mediana= pl.mediana(df5)
mediana
# Out:
#       Unnamed: 0                                             name    host_id  \
# 0              0                    Duplex avec vue, centre ville     269557
# 1              1                  Nice Flat in the center of Lyon     411285
# 2              2               Centre of old town,home sweet home     660135
# 3              3              Bel apartment, 2 rooms, Lyon center     670404
# 4              4  Quartier Terreaux 4/6 pers. Hyper centre / Clim     832917
# ...          ...                                              ...        ...
# 9886        9886                                      Suite Rumba  651608878
# 9887        9887                                      Suite Zelie  651608878
# 9888        9888                    Havre de Paix au Cœur du 7ème  666633599
# 9889        9889                           Le Duplex avec Rooftop   12466813
# 9890        9890                                          L’opéra  417340177
#
# ...

# %%
pl.valores_nulos(mediana)
# Out:
# ('Valores nulos por columna',
#  Unnamed: 0                                          0
#  name                                                0
#  host_id                                             0
#  host_name                                           2
#  host_since                                          2
#  host_location                                    1524
#  host_about                                       6066
#  host_response_time                               4656
#  host_response_rate                                  0
#  host_is_superhost                                 211
#  host_neighbourhood                               5544
#  host_listings_count                                 0
#  host_total_listings_count                           0
#  host_identity_verified                              2
#  neighbourhood_cleansed                              0
#  latitude                                            0
# ...

# %%
csv5 = pl.convertir_a_csv (mediana,'05_mediana.csv')

# %% [markdown]
# **CONSTANTE**

# %%
constante= pl.constante(df6,'last_review','host_is_superhost','host_neighbourhood',0)
constante
# Out:
#       Unnamed: 0                                             name    host_id  \
# 0              0                    Duplex avec vue, centre ville     269557
# 1              1                  Nice Flat in the center of Lyon     411285
# 2              2               Centre of old town,home sweet home     660135
# 3              3              Bel apartment, 2 rooms, Lyon center     670404
# 4              4  Quartier Terreaux 4/6 pers. Hyper centre / Clim     832917
# ...          ...                                              ...        ...
# 9886        9886                                      Suite Rumba  651608878
# 9887        9887                                      Suite Zelie  651608878
# 9888        9888                    Havre de Paix au Cœur du 7ème  666633599
# 9889        9889                           Le Duplex avec Rooftop   12466813
# 9890        9890                                          L’opéra  417340177
#
# ...

# %%
pl.valores_nulos(constante)
# Out:
# ('Valores nulos por columna',
#  Unnamed: 0                                          0
#  name                                                0
#  host_id                                             0
#  host_name                                           2
#  host_since                                          2
#  host_location                                    1524
#  host_about                                       6066
#  host_response_time                               4656
#  host_response_rate                               4656
#  host_is_superhost                                   0
#  host_neighbourhood                                  0
#  host_listings_count                                 2
#  host_total_listings_count                           2
#  host_identity_verified                              2
#  neighbourhood_cleansed                              0
#  latitude                                            0
# ...

# %%
csv6 = pl.convertir_a_csv (constante,'06_constante.csv')

# %% [markdown]
# **Limpio todo el df de Francia - Lyon**

# %%
francia_sin_nulos = pl.sustitucion_completa(df)
sin_nulos = pl.convertir_a_csv (francia_sin_nulos,'Francia_sin_nulos.csv')

# %%
sin_nulos = pl.valores_nulos(francia_sin_nulos)
sin_nulos
# Out:
# ('Valores nulos por columna',
#  Unnamed: 0                                       0
#  host_id                                          0
#  host_response_rate                               0
#  host_listings_count                              0
#  host_total_listings_count                        0
#  latitude                                         0
#  longitude                                        0
#  accommodates                                     0
#  bathrooms                                        0
#  bedrooms                                         0
#  beds                                             0
#  price                                            0
#  minimum_nights                                   0
#  maximum_nights                                   0
#  minimum_minimum_nights                           0
#  maximum_minimum_nights                           0
#  minimum_maximum_nights                           0
# ...
